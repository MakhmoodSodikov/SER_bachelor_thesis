# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model.base_model_train import train, extract_feature
from IPython.display import Audio
from IPython.core.display import display
from librosa.display import specshow
import matplotlib.pyplot as plt

# %%
model = train()
# Out:
#   0%|          | 0/1440 [00:00<?, ?it/s]
# model created!

# %%
display(Audio('makh.wav', autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
extract_feature('makh.wav')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-6195aa62a8ca> in <module>
# ----> 1 extract_feature('makh.wav')
#
# ~/PycharmProjects/SER_bachelor_thesis/model/base_model_train.py in extract_feature(file_name, mfcc, chroma, mel)
#      47         if mfcc:
#      48             mfccs = librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40)
# ---> 49             result = np.hstack((result, mfccs))
#      50         if chroma:
#      51             chroma = librosa.feature.chroma_stft(S=stft, sr=sample_rate)
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# ~/opt/anaconda3/envs/deeplearning/lib/python3.8/site-packages/numpy/core/shape_base.py in hstack(tup)
#     342     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     343     if arrs and arrs[0].ndim == 1:
# --> 344         return _nx.concatenate(arrs, 0)
#     345     else:
#     346         return _nx.concatenate(arrs, 1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)
